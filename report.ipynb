# %% [markdown]
# # Save predicted

# %%
import os
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from torchvision import transforms

# Import your model here
from src.model import MobileNetUNet  # Adjust the import according to your project structure

# Set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def load_model(model_path, device):
    """Load model from checkpoint"""
    model = MobileNetUNet(img_ch=1, seg_ch=4, num_classes=4).to(device)
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'] if 'model_state_dict' in checkpoint else checkpoint)
    model.eval()
    return model

# %%
def predict_masks(model, test_dir, output_dir):
    """Predict segmentation masks for all images in the test directory and save them."""
    os.makedirs(output_dir, exist_ok=True)

    # Class names for saving output
    class_names = ['No_Tumor', 'Glioma', 'Meningioma', 'Pituitary']
    for class_name in class_names:
        os.makedirs(os.path.join(output_dir, class_name), exist_ok=True)

    # Define normalization transform
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])

    true_classes = []
    pred_classes = []

    for class_idx, class_name in enumerate(class_names):
        class_dir = os.path.join(test_dir, 'image', class_name)
        image_files = [f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

        for img_file in tqdm(image_files, desc=f"Processing {class_name}"):
            img_path = os.path.join(class_dir, img_file)
            img = Image.open(img_path).convert('L').resize((256, 256))
            img_tensor = transform(img).unsqueeze(0).to(device)

            with torch.no_grad():
                seg_output, cls_output = model(img_tensor)
                seg_pred = torch.argmax(seg_output, dim=1).squeeze().cpu().numpy()
                cls_pred = torch.argmax(cls_output, dim=1).item()

            # Save segmentation mask to the folder corresponding to the true class
            output_path = os.path.join(output_dir, class_name, f"{os.path.splitext(img_file)[0]}.png")
            scaled_mask = (seg_pred * 85).astype(np.uint8)
            mask_img = Image.fromarray(scaled_mask)
            mask_img.save(output_path)

            true_classes.append(class_idx)
            pred_classes.append(cls_pred)
    
    return true_classes, pred_classes

def calculate_recall(true_classes, pred_classes):
    """Calculate recall based on true and predicted classes."""
    recall = {}
    for i in range(len(set(true_classes))):
        tp = sum((np.array(true_classes) == i) & (np.array(pred_classes) == i))
        fn = sum((np.array(true_classes) == i) & (np.array(pred_classes) != i))
        recall[i] = tp / (tp + fn) if (tp + fn) > 0 else 0
    return recall

# %%
def save_confusion_matrix(true_classes, pred_classes, class_names, output_path):
    cm = confusion_matrix(true_classes, pred_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.savefig(output_path, dpi=300, bbox_inches='tight')
    plt.close()

# %%
# Step 5: Main Execution Block
model_path = "kaggle/checkpoint/kaggle/working/Segment-and-Classify/checkpoint_new/best_model.pt"  # Update with your model path
test_dir = r"C:\Users\Xpeedent\Desktop\FPT\SP25\DBM\data_DBM\BrainTumor_Split_mask\test"  # Update with your test directory
output_dir = "pred_output/ori"  # Update with your output directory
confusion_matrix_path = os.path.join(output_dir, 'confusion_matrix.png')

# Load the model
model = load_model(model_path, device)

# Predict masks
true_classes, pred_classes = predict_masks(model, test_dir, output_dir)

# Calculate recall
recall_scores = calculate_recall(true_classes, pred_classes)
print("Recall Scores:", recall_scores)

# Save confusion matrix
save_confusion_matrix(true_classes, pred_classes, ['No_Tumor', 'Glioma', 'Meningioma', 'Pituitary'], confusion_matrix_path)

print("Prediction and evaluation complete!")
# Out:
# C:\Users\Xpeedent\AppData\Local\Temp\ipykernel_20696\3003062792.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# Processing No_Tumor: 100%|██████████| 160/160 [00:02<00:00, 55.76it/s]
# Processing Glioma: 100%|██████████| 65/65 [00:01<00:00, 57.60it/s]
# Processing Meningioma: 100%|██████████| 100/100 [00:01<00:00, 55.35it/s]
# Processing Pituitary: 100%|██████████| 100/100 [00:01<00:00, 55.04it/s]
# Recall Scores: {0: 0.9875, 1: 0.9692307692307692, 2: 0.93, 3: 0.99}
# Prediction and evaluation complete!

# %% [markdown]
# # Add _pred

# %%
import os
import shutil

def add_pred_to_png_files(root_folder):
    # Counter for renamed files
    renamed_count = 0
    
    # Walk through all folders and subfolders
    for folder_path, _, files in os.walk(root_folder):
        for file in files:
            # Check if file is a PNG
            if file.lower().endswith('.png'):
                # Construct the full file path
                file_path = os.path.join(folder_path, file)
                
                # Create the new filename with "_pred" before ".png"
                base_name = file[:-4]  # Remove the ".png" extension
                new_name = f"{base_name}_pred.png"
                new_file_path = os.path.join(folder_path, new_name)
                
                # Rename the file
                try:
                    shutil.move(file_path, new_file_path)
                    print(f"Renamed: {file} → {new_name}")
                    renamed_count += 1
                except Exception as e:
                    print(f"Error renaming {file}: {e}")
    
    # Print summary
    print(f"\nSummary:")
    print(f"Renamed {renamed_count} PNG files to include '_pred' suffix")
    
    return renamed_count

# Replace with your actual folder path
root_folder = r"C:\Users\Xpeedent\Desktop\Brain\pred_output\ori"

# Run the renaming process
renamed_files = add_pred_to_png_files(root_folder)
# Out:
# Renamed: confusion_matrix.png → confusion_matrix_pred.png
# Renamed: Tr-gl_0016.png → Tr-gl_0016_pred.png
# Renamed: Tr-gl_0055.png → Tr-gl_0055_pred.png
# Renamed: Tr-gl_0057.png → Tr-gl_0057_pred.png
# Renamed: Tr-gl_0061.png → Tr-gl_0061_pred.png
# Renamed: Tr-gl_0064.png → Tr-gl_0064_pred.png
# Renamed: Tr-gl_0084.png → Tr-gl_0084_pred.png
# Renamed: Tr-gl_0086.png → Tr-gl_0086_pred.png
# Renamed: Tr-gl_0159.png → Tr-gl_0159_pred.png
# Renamed: Tr-gl_0175.png → Tr-gl_0175_pred.png
# Renamed: Tr-gl_0176.png → Tr-gl_0176_pred.png
# Renamed: Tr-gl_0208.png → Tr-gl_0208_pred.png
# Renamed: Tr-gl_0216.png → Tr-gl_0216_pred.png
# Renamed: Tr-gl_0222.png → Tr-gl_0222_pred.png
# Renamed: Tr-gl_0238.png → Tr-gl_0238_pred.png
# Renamed: Tr-gl_0242.png → Tr-gl_0242_pred.png
# Renamed: Tr-gl_0244.png → Tr-gl_0244_pred.png
# Renamed: Tr-gl_0301.png → Tr-gl_0301_pred.png
# Renamed: Tr-gl_0359.png → Tr-gl_0359_pred.png
# Renamed: Tr-gl_0381.png → Tr-gl_0381_pred.png
# Renamed: Tr-gl_0415.png → Tr-gl_0415_pred.png
# Renamed: Tr-gl_0419.png → Tr-gl_0419_pred.png
# Renamed: Tr-gl_0425.png → Tr-gl_0425_pred.png
# Renamed: Tr-gl_0488.png → Tr-gl_0488_pred.png
# Renamed: Tr-gl_0500.png → Tr-gl_0500_pred.png
# Renamed: Tr-gl_0531.png → Tr-gl_0531_pred.png
# Renamed: Tr-gl_0548.png → Tr-gl_0548_pred.png
# Renamed: Tr-gl_0550.png → Tr-gl_0550_pred.png
# Renamed: Tr-gl_0559.png → Tr-gl_0559_pred.png
# Renamed: Tr-gl_0566.png → Tr-gl_0566_pred.png
# Renamed: Tr-gl_0571.png → Tr-gl_0571_pred.png
# Renamed: Tr-gl_0590.png → Tr-gl_0590_pred.png
# Renamed: Tr-gl_0624.png → Tr-gl_0624_pred.png
# Renamed: Tr-gl_0635.png → Tr-gl_0635_pred.png
# Renamed: Tr-gl_0638.png → Tr-gl_0638_pred.png
# Renamed: Tr-gl_0653.png → Tr-gl_0653_pred.png
# Renamed: Tr-gl_0659.png → Tr-gl_0659_pred.png
# Renamed: Tr-gl_0768.png → Tr-gl_0768_pred.png
# Renamed: Tr-gl_0791.png → Tr-gl_0791_pred.png
# Renamed: Tr-gl_0795.png → Tr-gl_0795_pred.png
# Renamed: Tr-gl_0866.png → Tr-gl_0866_pred.png
# Renamed: Tr-gl_0883.png → Tr-gl_0883_pred.png
# Renamed: Tr-gl_0893.png → Tr-gl_0893_pred.png
# Renamed: Tr-gl_0940.png → Tr-gl_0940_pred.png
# Renamed: Tr-gl_0943.png → Tr-gl_0943_pred.png
# Renamed: Tr-gl_1006.png → Tr-gl_1006_pred.png
# Renamed: Tr-gl_1009.png → Tr-gl_1009_pred.png
# Renamed: Tr-gl_1043.png → Tr-gl_1043_pred.png
# Renamed: Tr-gl_1055.png → Tr-gl_1055_pred.png
# Renamed: Tr-gl_1065.png → Tr-gl_1065_pred.png
# Renamed: Tr-gl_1148.png → Tr-gl_1148_pred.png
# Renamed: Tr-gl_1184.png → Tr-gl_1184_pred.png
# Renamed: Tr-gl_1197.png → Tr-gl_1197_pred.png
# Renamed: Tr-gl_1207.png → Tr-gl_1207_pred.png
# Renamed: Tr-gl_1222.png → Tr-gl_1222_pred.png
# Renamed: Tr-gl_1244.png → Tr-gl_1244_pred.png
# Renamed: Tr-gl_1258.png → Tr-gl_1258_pred.png
# Renamed: Tr-gl_1259.png → Tr-gl_1259_pred.png
# Renamed: Tr-gl_1268.png → Tr-gl_1268_pred.png
# Renamed: Tr-gl_1273.png → Tr-gl_1273_pred.png
# Renamed: Tr-gl_1274.png → Tr-gl_1274_pred.png
# Renamed: Tr-gl_1281.png → Tr-gl_1281_pred.png
# Renamed: Tr-gl_1295.png → Tr-gl_1295_pred.png
# Renamed: Tr-gl_1301.png → Tr-gl_1301_pred.png
# Renamed: Tr-gl_1304.png → Tr-gl_1304_pred.png
# Renamed: Tr-gl_1306.png → Tr-gl_1306_pred.png
# Renamed: Tr-me_0012.png → Tr-me_0012_pred.png
# Renamed: Tr-me_0032.png → Tr-me_0032_pred.png
# Renamed: Tr-me_0034.png → Tr-me_0034_pred.png
# Renamed: Tr-me_0037.png → Tr-me_0037_pred.png
# Renamed: Tr-me_0039.png → Tr-me_0039_pred.png
# Renamed: Tr-me_0051.png → Tr-me_0051_pred.png
# Renamed: Tr-me_0053.png → Tr-me_0053_pred.png
# Renamed: Tr-me_0079.png → Tr-me_0079_pred.png
# Renamed: Tr-me_0088.png → Tr-me_0088_pred.png
# Renamed: Tr-me_0089.png → Tr-me_0089_pred.png
# Renamed: Tr-me_0097.png → Tr-me_0097_pred.png
# Renamed: Tr-me_0103.png → Tr-me_0103_pred.png
# Renamed: Tr-me_0104.png → Tr-me_0104_pred.png
# Renamed: Tr-me_0108.png → Tr-me_0108_pred.png
# Renamed: Tr-me_0114.png → Tr-me_0114_pred.png
# Renamed: Tr-me_0115.png → Tr-me_0115_pred.png
# Renamed: Tr-me_0126.png → Tr-me_0126_pred.png
# Renamed: Tr-me_0139.png → Tr-me_0139_pred.png
# Renamed: Tr-me_0154.png → Tr-me_0154_pred.png
# Renamed: Tr-me_0171.png → Tr-me_0171_pred.png
# Renamed: Tr-me_0175.png → Tr-me_0175_pred.png
# Renamed: Tr-me_0179.png → Tr-me_0179_pred.png
# Renamed: Tr-me_0210.png → Tr-me_0210_pred.png
# Renamed: Tr-me_0217.png → Tr-me_0217_pred.png
# Renamed: Tr-me_0228.png → Tr-me_0228_pred.png
# Renamed: Tr-me_0234.png → Tr-me_0234_pred.png
# Renamed: Tr-me_0237.png → Tr-me_0237_pred.png
# Renamed: Tr-me_0239.png → Tr-me_0239_pred.png
# Renamed: Tr-me_0242.png → Tr-me_0242_pred.png
# Renamed: Tr-me_0247.png → Tr-me_0247_pred.png
# Renamed: Tr-me_0252.png → Tr-me_0252_pred.png
# Renamed: Tr-me_0264.png → Tr-me_0264_pred.png
# Renamed: Tr-me_0285.png → Tr-me_0285_pred.png
# Renamed: Tr-me_0296.png → Tr-me_0296_pred.png
# Renamed: Tr-me_0300.png → Tr-me_0300_pred.png
# Renamed: Tr-me_0312.png → Tr-me_0312_pred.png
# Renamed: Tr-me_0316.png → Tr-me_0316_pred.png
# Renamed: Tr-me_0360.png → Tr-me_0360_pred.png
# Renamed: Tr-me_0364.png → Tr-me_0364_pred.png
# Renamed: Tr-me_0368.png → Tr-me_0368_pred.png
# Renamed: Tr-me_0379.png → Tr-me_0379_pred.png
# Renamed: Tr-me_0383.png → Tr-me_0383_pred.png
# Renamed: Tr-me_0386.png → Tr-me_0386_pred.png
# Renamed: Tr-me_0390.png → Tr-me_0390_pred.png
# Renamed: Tr-me_0399.png → Tr-me_0399_pred.png
# Renamed: Tr-me_0407.png → Tr-me_0407_pred.png
# Renamed: Tr-me_0409.png → Tr-me_0409_pred.png
# Renamed: Tr-me_0449.png → Tr-me_0449_pred.png
# Renamed: Tr-me_0452.png → Tr-me_0452_pred.png
# Renamed: Tr-me_0479.png → Tr-me_0479_pred.png
# Renamed: Tr-me_0484.png → Tr-me_0484_pred.png
# Renamed: Tr-me_0490.png → Tr-me_0490_pred.png
# Renamed: Tr-me_0538.png → Tr-me_0538_pred.png
# Renamed: Tr-me_0571.png → Tr-me_0571_pred.png
# Renamed: Tr-me_0580.png → Tr-me_0580_pred.png
# Renamed: Tr-me_0587.png → Tr-me_0587_pred.png
# Renamed: Tr-me_0597.png → Tr-me_0597_pred.png
# Renamed: Tr-me_0615.png → Tr-me_0615_pred.png
# Renamed: Tr-me_0628.png → Tr-me_0628_pred.png
# Renamed: Tr-me_0629.png → Tr-me_0629_pred.png
# Renamed: Tr-me_0645.png → Tr-me_0645_pred.png
# Renamed: Tr-me_0649.png → Tr-me_0649_pred.png
# Renamed: Tr-me_0669.png → Tr-me_0669_pred.png
# Renamed: Tr-me_0689.png → Tr-me_0689_pred.png
# Renamed: Tr-me_0704.png → Tr-me_0704_pred.png
# Renamed: Tr-me_0708.png → Tr-me_0708_pred.png
# Renamed: Tr-me_0723.png → Tr-me_0723_pred.png
# Renamed: Tr-me_0743.png → Tr-me_0743_pred.png
# Renamed: Tr-me_0759.png → Tr-me_0759_pred.png
# Renamed: Tr-me_0766.png → Tr-me_0766_pred.png
# Renamed: Tr-me_0796.png → Tr-me_0796_pred.png
# Renamed: Tr-me_0803.png → Tr-me_0803_pred.png
# Renamed: Tr-me_0807.png → Tr-me_0807_pred.png
# Renamed: Tr-me_0841.png → Tr-me_0841_pred.png
# Renamed: Tr-me_0870.png → Tr-me_0870_pred.png
# Renamed: Tr-me_0878.png → Tr-me_0878_pred.png
# Renamed: Tr-me_0883.png → Tr-me_0883_pred.png
# Renamed: Tr-me_0884.png → Tr-me_0884_pred.png
# Renamed: Tr-me_0917.png → Tr-me_0917_pred.png
# Renamed: Tr-me_0927.png → Tr-me_0927_pred.png
# Renamed: Tr-me_0949.png → Tr-me_0949_pred.png
# Renamed: Tr-me_1014.png → Tr-me_1014_pred.png
# Renamed: Tr-me_1015.png → Tr-me_1015_pred.png
# Renamed: Tr-me_1017.png → Tr-me_1017_pred.png
# Renamed: Tr-me_1078.png → Tr-me_1078_pred.png
# Renamed: Tr-me_1084.png → Tr-me_1084_pred.png
# Renamed: Tr-me_1102.png → Tr-me_1102_pred.png
# Renamed: Tr-me_1116.png → Tr-me_1116_pred.png
# Renamed: Tr-me_1132.png → Tr-me_1132_pred.png
# Renamed: Tr-me_1137.png → Tr-me_1137_pred.png
# Renamed: Tr-me_1144.png → Tr-me_1144_pred.png
# Renamed: Tr-me_1168.png → Tr-me_1168_pred.png
# Renamed: Tr-me_1182.png → Tr-me_1182_pred.png
# Renamed: Tr-me_1235.png → Tr-me_1235_pred.png
# Renamed: Tr-me_1248.png → Tr-me_1248_pred.png
# Renamed: Tr-me_1282.png → Tr-me_1282_pred.png
# Renamed: Tr-me_1304.png → Tr-me_1304_pred.png
# Renamed: Tr-me_1312.png → Tr-me_1312_pred.png
# Renamed: Tr-me_1315.png → Tr-me_1315_pred.png
# Renamed: Tr-me_1323.png → Tr-me_1323_pred.png
# Renamed: Tr-no_0013.png → Tr-no_0013_pred.png
# Renamed: Tr-no_0023.png → Tr-no_0023_pred.png
# Renamed: Tr-no_0051.png → Tr-no_0051_pred.png
# Renamed: Tr-no_0054.png → Tr-no_0054_pred.png
# Renamed: Tr-no_0061.png → Tr-no_0061_pred.png
# Renamed: Tr-no_0065.png → Tr-no_0065_pred.png
# Renamed: Tr-no_0088.png → Tr-no_0088_pred.png
# Renamed: Tr-no_0093.png → Tr-no_0093_pred.png
# Renamed: Tr-no_0096.png → Tr-no_0096_pred.png
# Renamed: Tr-no_0114.png → Tr-no_0114_pred.png
# Renamed: Tr-no_0130.png → Tr-no_0130_pred.png
# Renamed: Tr-no_0135.png → Tr-no_0135_pred.png
# Renamed: Tr-no_0142.png → Tr-no_0142_pred.png
# Renamed: Tr-no_0146.png → Tr-no_0146_pred.png
# Renamed: Tr-no_0161.png → Tr-no_0161_pred.png
# Renamed: Tr-no_0163.png → Tr-no_0163_pred.png
# Renamed: Tr-no_0178.png → Tr-no_0178_pred.png
# Renamed: Tr-no_0186.png → Tr-no_0186_pred.png
# Renamed: Tr-no_0189.png → Tr-no_0189_pred.png
# Renamed: Tr-no_0191.png → Tr-no_0191_pred.png
# Renamed: Tr-no_0198.png → Tr-no_0198_pred.png
# Renamed: Tr-no_0206.png → Tr-no_0206_pred.png
# Renamed: Tr-no_0209.png → Tr-no_0209_pred.png
# Renamed: Tr-no_0224.png → Tr-no_0224_pred.png
# Renamed: Tr-no_0228.png → Tr-no_0228_pred.png
# Renamed: Tr-no_0234.png → Tr-no_0234_pred.png
# Renamed: Tr-no_0255.png → Tr-no_0255_pred.png
# Renamed: Tr-no_0283.png → Tr-no_0283_pred.png
# Renamed: Tr-no_0285.png → Tr-no_0285_pred.png
# Renamed: Tr-no_0292.png → Tr-no_0292_pred.png
# Renamed: Tr-no_0313.png → Tr-no_0313_pred.png
# Renamed: Tr-no_0318.png → Tr-no_0318_pred.png
# Renamed: Tr-no_0326.png → Tr-no_0326_pred.png
# Renamed: Tr-no_0327.png → Tr-no_0327_pred.png
# Renamed: Tr-no_0333.png → Tr-no_0333_pred.png
# Renamed: Tr-no_0334.png → Tr-no_0334_pred.png
# Renamed: Tr-no_0350.png → Tr-no_0350_pred.png
# Renamed: Tr-no_0393.png → Tr-no_0393_pred.png
# Renamed: Tr-no_0407.png → Tr-no_0407_pred.png
# Renamed: Tr-no_0429.png → Tr-no_0429_pred.png
# Renamed: Tr-no_0432.png → Tr-no_0432_pred.png
# Renamed: Tr-no_0435.png → Tr-no_0435_pred.png
# Renamed: Tr-no_0440.png → Tr-no_0440_pred.png
# Renamed: Tr-no_0447.png → Tr-no_0447_pred.png
# Renamed: Tr-no_0449.png → Tr-no_0449_pred.png
# Renamed: Tr-no_0451.png → Tr-no_0451_pred.png
# Renamed: Tr-no_0457.png → Tr-no_0457_pred.png
# Renamed: Tr-no_0466.png → Tr-no_0466_pred.png
# Renamed: Tr-no_0469.png → Tr-no_0469_pred.png
# Renamed: Tr-no_0476.png → Tr-no_0476_pred.png
# Renamed: Tr-no_0501.png → Tr-no_0501_pred.png
# Renamed: Tr-no_0505.png → Tr-no_0505_pred.png
# Renamed: Tr-no_0514.png → Tr-no_0514_pred.png
# Renamed: Tr-no_0538.png → Tr-no_0538_pred.png
# Renamed: Tr-no_0541.png → Tr-no_0541_pred.png
# Renamed: Tr-no_0542.png → Tr-no_0542_pred.png
# Renamed: Tr-no_0546.png → Tr-no_0546_pred.png
# Renamed: Tr-no_0548.png → Tr-no_0548_pred.png
# Renamed: Tr-no_0552.png → Tr-no_0552_pred.png
# Renamed: Tr-no_0563.png → Tr-no_0563_pred.png
# Renamed: Tr-no_0569.png → Tr-no_0569_pred.png
# Renamed: Tr-no_0592.png → Tr-no_0592_pred.png
# Renamed: Tr-no_0600.png → Tr-no_0600_pred.png
# Renamed: Tr-no_0644.png → Tr-no_0644_pred.png
# Renamed: Tr-no_0646.png → Tr-no_0646_pred.png
# Renamed: Tr-no_0664.png → Tr-no_0664_pred.png
# Renamed: Tr-no_0689.png → Tr-no_0689_pred.png
# Renamed: Tr-no_0696.png → Tr-no_0696_pred.png
# Renamed: Tr-no_0704.png → Tr-no_0704_pred.png
# Renamed: Tr-no_0727.png → Tr-no_0727_pred.png
# Renamed: Tr-no_0735.png → Tr-no_0735_pred.png
# Renamed: Tr-no_0740.png → Tr-no_0740_pred.png
# Renamed: Tr-no_0741.png → Tr-no_0741_pred.png
# Renamed: Tr-no_0747.png → Tr-no_0747_pred.png
# Renamed: Tr-no_0758.png → Tr-no_0758_pred.png
# Renamed: Tr-no_0775.png → Tr-no_0775_pred.png
# Renamed: Tr-no_0777.png → Tr-no_0777_pred.png
# Renamed: Tr-no_0778.png → Tr-no_0778_pred.png
# Renamed: Tr-no_0781.png → Tr-no_0781_pred.png
# Renamed: Tr-no_0788.png → Tr-no_0788_pred.png
# Renamed: Tr-no_0810.png → Tr-no_0810_pred.png
# Renamed: Tr-no_0817.png → Tr-no_0817_pred.png
# Renamed: Tr-no_0821.png → Tr-no_0821_pred.png
# Renamed: Tr-no_0859.png → Tr-no_0859_pred.png
# Renamed: Tr-no_0864.png → Tr-no_0864_pred.png
# Renamed: Tr-no_0865.png → Tr-no_0865_pred.png
# Renamed: Tr-no_0877.png → Tr-no_0877_pred.png
# Renamed: Tr-no_0919.png → Tr-no_0919_pred.png
# Renamed: Tr-no_0928.png → Tr-no_0928_pred.png
# Renamed: Tr-no_0939.png → Tr-no_0939_pred.png
# Renamed: Tr-no_0940.png → Tr-no_0940_pred.png
# Renamed: Tr-no_0946.png → Tr-no_0946_pred.png
# Renamed: Tr-no_0958.png → Tr-no_0958_pred.png
# Renamed: Tr-no_1010.png → Tr-no_1010_pred.png
# Renamed: Tr-no_1022.png → Tr-no_1022_pred.png
# Renamed: Tr-no_1034.png → Tr-no_1034_pred.png
# Renamed: Tr-no_1043.png → Tr-no_1043_pred.png
# Renamed: Tr-no_1083.png → Tr-no_1083_pred.png
# Renamed: Tr-no_1093.png → Tr-no_1093_pred.png
# Renamed: Tr-no_1098.png → Tr-no_1098_pred.png
# Renamed: Tr-no_1103.png → Tr-no_1103_pred.png
# Renamed: Tr-no_1116.png → Tr-no_1116_pred.png
# Renamed: Tr-no_1130.png → Tr-no_1130_pred.png
# Renamed: Tr-no_1133.png → Tr-no_1133_pred.png
# Renamed: Tr-no_1140.png → Tr-no_1140_pred.png
# Renamed: Tr-no_1149.png → Tr-no_1149_pred.png
# Renamed: Tr-no_1161.png → Tr-no_1161_pred.png
# Renamed: Tr-no_1182.png → Tr-no_1182_pred.png
# Renamed: Tr-no_1195.png → Tr-no_1195_pred.png
# Renamed: Tr-no_1197.png → Tr-no_1197_pred.png
# Renamed: Tr-no_1206.png → Tr-no_1206_pred.png
# Renamed: Tr-no_1209.png → Tr-no_1209_pred.png
# Renamed: Tr-no_1220.png → Tr-no_1220_pred.png
# Renamed: Tr-no_1221.png → Tr-no_1221_pred.png
# Renamed: Tr-no_1232.png → Tr-no_1232_pred.png
# Renamed: Tr-no_1236.png → Tr-no_1236_pred.png
# Renamed: Tr-no_1247.png → Tr-no_1247_pred.png
# Renamed: Tr-no_1266.png → Tr-no_1266_pred.png
# Renamed: Tr-no_1285.png → Tr-no_1285_pred.png
# Renamed: Tr-no_1287.png → Tr-no_1287_pred.png
# Renamed: Tr-no_1300.png → Tr-no_1300_pred.png
# Renamed: Tr-no_1301.png → Tr-no_1301_pred.png
# Renamed: Tr-no_1309.png → Tr-no_1309_pred.png
# Renamed: Tr-no_1310.png → Tr-no_1310_pred.png
# Renamed: Tr-no_1316.png → Tr-no_1316_pred.png
# Renamed: Tr-no_1327.png → Tr-no_1327_pred.png
# Renamed: Tr-no_1330.png → Tr-no_1330_pred.png
# Renamed: Tr-no_1342.png → Tr-no_1342_pred.png
# Renamed: Tr-no_1354.png → Tr-no_1354_pred.png
# Renamed: Tr-no_1372.png → Tr-no_1372_pred.png
# Renamed: Tr-no_1385.png → Tr-no_1385_pred.png
# Renamed: Tr-no_1393.png → Tr-no_1393_pred.png
# Renamed: Tr-no_1399.png → Tr-no_1399_pred.png
# Renamed: Tr-no_1402.png → Tr-no_1402_pred.png
# Renamed: Tr-no_1409.png → Tr-no_1409_pred.png
# Renamed: Tr-no_1429.png → Tr-no_1429_pred.png
# Renamed: Tr-no_1436.png → Tr-no_1436_pred.png
# Renamed: Tr-no_1437.png → Tr-no_1437_pred.png
# Renamed: Tr-no_1442.png → Tr-no_1442_pred.png
# Renamed: Tr-no_1448.png → Tr-no_1448_pred.png
# Renamed: Tr-no_1466.png → Tr-no_1466_pred.png
# Renamed: Tr-no_1470.png → Tr-no_1470_pred.png
# Renamed: Tr-no_1490.png → Tr-no_1490_pred.png
# Renamed: Tr-no_1493.png → Tr-no_1493_pred.png
# Renamed: Tr-no_1494.png → Tr-no_1494_pred.png
# Renamed: Tr-no_1508.png → Tr-no_1508_pred.png
# Renamed: Tr-no_1516.png → Tr-no_1516_pred.png
# Renamed: Tr-no_1518.png → Tr-no_1518_pred.png
# Renamed: Tr-no_1547.png → Tr-no_1547_pred.png
# Renamed: Tr-no_1553.png → Tr-no_1553_pred.png
# Renamed: Tr-no_1554.png → Tr-no_1554_pred.png
# Renamed: Tr-no_1560.png → Tr-no_1560_pred.png
# Renamed: Tr-no_1570.png → Tr-no_1570_pred.png
# Renamed: Tr-no_1574.png → Tr-no_1574_pred.png
# Renamed: Tr-no_1578.png → Tr-no_1578_pred.png
# Renamed: Tr-no_1579.png → Tr-no_1579_pred.png
# Renamed: Tr-no_1582.png → Tr-no_1582_pred.png
# Renamed: Tr-no_1585.png → Tr-no_1585_pred.png
# Renamed: Tr-no_1587.png → Tr-no_1587_pred.png
# Renamed: Tr-no_1589.png → Tr-no_1589_pred.png
# Renamed: Tr-pi_0010.png → Tr-pi_0010_pred.png
# Renamed: Tr-pi_0029.png → Tr-pi_0029_pred.png
# Renamed: Tr-pi_0031.png → Tr-pi_0031_pred.png
# Renamed: Tr-pi_0038.png → Tr-pi_0038_pred.png
# Renamed: Tr-pi_0040.png → Tr-pi_0040_pred.png
# Renamed: Tr-pi_0055.png → Tr-pi_0055_pred.png
# Renamed: Tr-pi_0057.png → Tr-pi_0057_pred.png
# Renamed: Tr-pi_0091.png → Tr-pi_0091_pred.png
# Renamed: Tr-pi_0104.png → Tr-pi_0104_pred.png
# Renamed: Tr-pi_0105.png → Tr-pi_0105_pred.png
# Renamed: Tr-pi_0117.png → Tr-pi_0117_pred.png
# Renamed: Tr-pi_0123.png → Tr-pi_0123_pred.png
# Renamed: Tr-pi_0124.png → Tr-pi_0124_pred.png
# Renamed: Tr-pi_0131.png → Tr-pi_0131_pred.png
# Renamed: Tr-pi_0135.png → Tr-pi_0135_pred.png
# Renamed: Tr-pi_0136.png → Tr-pi_0136_pred.png
# Renamed: Tr-pi_0147.png → Tr-pi_0147_pred.png
# Renamed: Tr-pi_0161.png → Tr-pi_0161_pred.png
# Renamed: Tr-pi_0177.png → Tr-pi_0177_pred.png
# Renamed: Tr-pi_0217.png → Tr-pi_0217_pred.png
# Renamed: Tr-pi_0221.png → Tr-pi_0221_pred.png
# Renamed: Tr-pi_0226.png → Tr-pi_0226_pred.png
# Renamed: Tr-pi_0270.png → Tr-pi_0270_pred.png
# Renamed: Tr-pi_0277.png → Tr-pi_0277_pred.png
# Renamed: Tr-pi_0288.png → Tr-pi_0288_pred.png
# Renamed: Tr-pi_0300.png → Tr-pi_0300_pred.png
# Renamed: Tr-pi_0303.png → Tr-pi_0303_pred.png
# Renamed: Tr-pi_0306.png → Tr-pi_0306_pred.png
# Renamed: Tr-pi_0309.png → Tr-pi_0309_pred.png
# Renamed: Tr-pi_0315.png → Tr-pi_0315_pred.png
# Renamed: Tr-pi_0322.png → Tr-pi_0322_pred.png
# Renamed: Tr-pi_0341.png → Tr-pi_0341_pred.png
# Renamed: Tr-pi_0368.png → Tr-pi_0368_pred.png
# Renamed: Tr-pi_0393.png → Tr-pi_0393_pred.png
# Renamed: Tr-pi_0396.png → Tr-pi_0396_pred.png
# Renamed: Tr-pi_0408.png → Tr-pi_0408_pred.png
# Renamed: Tr-pi_0414.png → Tr-pi_0414_pred.png
# Renamed: Tr-pi_0482.png → Tr-pi_0482_pred.png
# Renamed: Tr-pi_0486.png → Tr-pi_0486_pred.png
# Renamed: Tr-pi_0491.png → Tr-pi_0491_pred.png
# Renamed: Tr-pi_0504.png → Tr-pi_0504_pred.png
# Renamed: Tr-pi_0509.png → Tr-pi_0509_pred.png
# Renamed: Tr-pi_0514.png → Tr-pi_0514_pred.png
# Renamed: Tr-pi_0518.png → Tr-pi_0518_pred.png
# Renamed: Tr-pi_0527.png → Tr-pi_0527_pred.png
# Renamed: Tr-pi_0540.png → Tr-pi_0540_pred.png
# Renamed: Tr-pi_0545.png → Tr-pi_0545_pred.png
# Renamed: Tr-pi_0597.png → Tr-pi_0597_pred.png
# Renamed: Tr-pi_0600.png → Tr-pi_0600_pred.png
# Renamed: Tr-pi_0634.png → Tr-pi_0634_pred.png
# Renamed: Tr-pi_0639.png → Tr-pi_0639_pred.png
# Renamed: Tr-pi_0646.png → Tr-pi_0646_pred.png
# Renamed: Tr-pi_0709.png → Tr-pi_0709_pred.png
# Renamed: Tr-pi_0751.png → Tr-pi_0751_pred.png
# Renamed: Tr-pi_0761.png → Tr-pi_0761_pred.png
# Renamed: Tr-pi_0784.png → Tr-pi_0784_pred.png
# Renamed: Tr-pi_0797.png → Tr-pi_0797_pred.png
# Renamed: Tr-pi_0823.png → Tr-pi_0823_pred.png
# Renamed: Tr-pi_0837.png → Tr-pi_0837_pred.png
# Renamed: Tr-pi_0838.png → Tr-pi_0838_pred.png
# Renamed: Tr-pi_0859.png → Tr-pi_0859_pred.png
# Renamed: Tr-pi_0861.png → Tr-pi_0861_pred.png
# Renamed: Tr-pi_0892.png → Tr-pi_0892_pred.png
# Renamed: Tr-pi_0902.png → Tr-pi_0902_pred.png
# Renamed: Tr-pi_0909.png → Tr-pi_0909_pred.png
# Renamed: Tr-pi_0917.png → Tr-pi_0917_pred.png
# Renamed: Tr-pi_0930.png → Tr-pi_0930_pred.png
# Renamed: Tr-pi_0969.png → Tr-pi_0969_pred.png
# Renamed: Tr-pi_0979.png → Tr-pi_0979_pred.png
# Renamed: Tr-pi_0985.png → Tr-pi_0985_pred.png
# Renamed: Tr-pi_1024.png → Tr-pi_1024_pred.png
# Renamed: Tr-pi_1028.png → Tr-pi_1028_pred.png
# Renamed: Tr-pi_1032.png → Tr-pi_1032_pred.png
# Renamed: Tr-pi_1051.png → Tr-pi_1051_pred.png
# Renamed: Tr-pi_1070.png → Tr-pi_1070_pred.png
# Renamed: Tr-pi_1077.png → Tr-pi_1077_pred.png
# Renamed: Tr-pi_1083.png → Tr-pi_1083_pred.png
# Renamed: Tr-pi_1084.png → Tr-pi_1084_pred.png
# Renamed: Tr-pi_1110.png → Tr-pi_1110_pred.png
# Renamed: Tr-pi_1115.png → Tr-pi_1115_pred.png
# Renamed: Tr-pi_1126.png → Tr-pi_1126_pred.png
# Renamed: Tr-pi_1177.png → Tr-pi_1177_pred.png
# Renamed: Tr-pi_1179.png → Tr-pi_1179_pred.png
# Renamed: Tr-pi_1181.png → Tr-pi_1181_pred.png
# Renamed: Tr-pi_1208.png → Tr-pi_1208_pred.png
# Renamed: Tr-pi_1215.png → Tr-pi_1215_pred.png
# Renamed: Tr-pi_1238.png → Tr-pi_1238_pred.png
# Renamed: Tr-pi_1256.png → Tr-pi_1256_pred.png
# Renamed: Tr-pi_1266.png → Tr-pi_1266_pred.png
# Renamed: Tr-pi_1271.png → Tr-pi_1271_pred.png
# Renamed: Tr-pi_1277.png → Tr-pi_1277_pred.png
# Renamed: Tr-pi_1314.png → Tr-pi_1314_pred.png
# Renamed: Tr-pi_1324.png → Tr-pi_1324_pred.png
# Renamed: Tr-pi_1363.png → Tr-pi_1363_pred.png
# Renamed: Tr-pi_1377.png → Tr-pi_1377_pred.png
# Renamed: Tr-pi_1398.png → Tr-pi_1398_pred.png
# Renamed: Tr-pi_1429.png → Tr-pi_1429_pred.png
# Renamed: Tr-pi_1436.png → Tr-pi_1436_pred.png
# Renamed: Tr-pi_1439.png → Tr-pi_1439_pred.png
# Renamed: Tr-pi_1443.png → Tr-pi_1443_pred.png
#
# Summary:
# Renamed 426 PNG files to include '_pred' suffix

# %% [markdown]
# # Compare folder

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm

def dice_coef_metric(pred_mask, gt_mask, smooth=1e-6):
    """
    Calculate Dice coefficient between tumor regions.
    
    Args:
        pred_mask: Predicted binary mask
        gt_mask: Ground truth binary mask
        smooth: Smoothing factor to avoid division by zero
            
    Returns:
        Dice coefficient score (float)
    """
    # Convert masks to binary
    pred_binary = pred_mask > 0
    gt_binary = gt_mask > 0
    
    # Calculate intersection and union
    intersection = np.sum(pred_binary & gt_binary)
    pred_area = np.sum(pred_binary)
    gt_area = np.sum(gt_binary)
    
    # Calculate Dice coefficient
    denominator = pred_area + gt_area
    
    # Handle edge cases
    if denominator == 0:
        return 1.0  # Both masks are empty
    return (2. * intersection + smooth) / (denominator + smooth)

def calculate_average_dice(test_mask_dir, pred_mask_dir):
    """
    Calculate average Dice scores by comparing test masks with predicted masks.
    
    Args:
        test_mask_dir: Directory containing ground truth masks
        pred_mask_dir: Directory containing predicted masks
        
    Returns:
        Dictionary with average Dice scores for each class
    """
    # Define class names
    class_names = ['No_Tumor', 'Glioma', 'Meningioma', 'Pituitary']
    
    # Initialize results dictionary
    average_dice_scores = {class_name: [] for class_name in class_names}
    
    # Process each class
    for class_name in class_names:
        gt_mask_dir = os.path.join(test_mask_dir, 'mask', class_name)
        if not os.path.exists(gt_mask_dir):
            print(f"Ground truth mask directory for {class_name} not found, skipping.")
            continue
        
        gt_masks = [f for f in os.listdir(gt_mask_dir) if f.endswith('.png')]
        if not gt_masks:
            print(f"No ground truth masks found for {class_name}, skipping.")
            continue
        
        print(f"Processing {len(gt_masks)} masks for class {class_name}...")
        
        # Process each mask
        for mask_file in tqdm(gt_masks, desc=f"Class {class_name}"):
            gt_path = os.path.join(gt_mask_dir, mask_file)
            gt_mask = np.array(Image.open(gt_path).convert('L').resize((256, 256)))
            
            # Normalize ground truth mask if needed
            if gt_mask.max() > 3:
                gt_mask = (gt_mask / 255 * 3).astype(np.uint8)
            
            # Find corresponding predicted mask
            pred_path = os.path.join(pred_mask_dir, class_name, f"{os.path.splitext(mask_file)[0]}_pred.png")
            if not os.path.exists(pred_path):
                print(f"No prediction found for {mask_file}, skipping.")
                continue
            
            pred_mask = np.array(Image.open(pred_path).convert('L').resize((256, 256)))
            if pred_mask.max() > 3:
                pred_mask = (pred_mask / 85).astype(np.uint8)
            
            # Calculate Dice score
            dice_score = dice_coef_metric(pred_mask, gt_mask)
            average_dice_scores[class_name].append(dice_score)
    
    # Calculate average for each class
    average_results = {class_name: np.mean(scores) if scores else 0 for class_name, scores in average_dice_scores.items()}
    
    return average_results

# %%
# Main execution block
def main():
    # Set paths
    test_dir = r"C:\Users\Xpeedent\Desktop\FPT\SP25\DBM\data_DBM\BrainTumor_Split_mask\test" # Update with your test directory
    pred_dir = r"C:\Users\Xpeedent\Desktop\Brain\pred_output\ori"  # Update with your predictions directory
    
    # Calculate average Dice scores
    print("Calculating average Dice scores...")
    average_dice_scores = calculate_average_dice(test_dir, pred_dir)
    
    # Print average Dice scores
    print("\nAverage Dice Scores:")
    for class_name, score in average_dice_scores.items():
        print(f"{class_name}: {score:.4f}")

# Execute the main function
main()
# Out:
# Calculating average Dice scores...
# Processing 160 masks for class No_Tumor...
# Class No_Tumor: 100%|██████████| 160/160 [00:00<00:00, 279.07it/s]
# Processing 65 masks for class Glioma...
# Class Glioma: 100%|██████████| 65/65 [00:00<00:00, 110.21it/s]
# Processing 100 masks for class Meningioma...
# Class Meningioma: 100%|██████████| 100/100 [00:00<00:00, 109.83it/s]
# Processing 100 masks for class Pituitary...
# Class Pituitary: 100%|██████████| 100/100 [00:00<00:00, 106.86it/s]
# Average Dice Scores:
# No_Tumor: 1.0000
# Glioma: 0.7550
# Meningioma: 0.8483
# Pituitary: 0.8993
